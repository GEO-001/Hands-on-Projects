# %% [markdown]
# # __Introduction__

# %% [markdown]
# This page contains my preliminary efforts on map creation during my undergraduate studies at the Federal University of Agriculture, Abeokuta, Nigeria (FUNAAB).
# ### Software
# - ArcView 3.3

# %% [markdown]
# ---

# %% [markdown]
# ## Tree Species Distribution within FUNAAB

# %% [markdown]
# The map below shows the distribution of tree species across selected landmarks within FUNAAB

# %%
from IPython.display import Image, display
display(Image(filename='map_pictures/tree_spp_in_FUNAAB.png'))

# %% [markdown]
# ##### Selected landmarks
# - College of Animal Sciences (COLANIM) Farm
# - College of Management Studies (COLMAS)
# - Vice-Chancellor's lodge (V.C lodge)
# - Forest Nursery
# - The University Senate administrative building (Senate)
# - Female Hostel (Marble lodge)
#
# ##### Identified Tree Species
# - Irvinga gabonensis
# - Treculia Africana
# - Tremia guinensis
# - Anthocleista spp.
# - Ceiba petandra

# %% [markdown]
# ---

# %% [markdown]
# ## Lekan Are Dam, Odeda, Abeokuta, Ogun State, Nigeria

# %% [markdown]
# In this map, Lekan Are Dam, a major dam in ogun state of Nigeria is visualized

# %%
display(Image(filename='map_pictures/la_dam.png'))

# %% [markdown]
# ---

# %% [markdown]
# ## Major Towns in Oyo State, Nigeria

# %%
display(Image(filename='map_pictures/oyo_towns.png'))

# %% [markdown]
# ---

# %% [markdown]
# ## Ose River Park, Ondo State, Nigeria

# %%
display(Image(filename='map_pictures/ose_river_park.png'))

# %% [markdown]
# ---

# %% [markdown]
# ## Cottage Industries in Abeokuta

# %%
display(Image(filename='map_pictures/abk_cot_ind.png'))

# %% [markdown]
# ---

# %% [markdown]
# ## Rivers in Ogun State, Nigeria

# %%
display(Image(filename='map_pictures/ogun_rivers.png'))

# %% [markdown]
# ---

# %% [markdown]
# ## Major fish markets in Abeokuta, Ogun, Nigeria

# %%
display(Image(filename='map_pictures/fish_farm.png'))

# %% [markdown]
# ----------

# %% [markdown]
# ## Ebonyi State, Nigeria

# %% [markdown]
# Area of Interest: Ten (10) towns within Abakaliki and Afikpo North Local Government Areas (LGA) of Ebonyi State, South East of Nigeria.

# %%
display(Image(filename='map_pictures/ebsu.png'))

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Petrol Stations within Abeokuta North, Ogun, Nigeria

# %%
display(Image(filename='map_pictures/abk_fill_st.png'))

# %% [markdown]
# ---
